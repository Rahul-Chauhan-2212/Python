# %%
name = input("What is your name?") # input function
# Out:
# What is your name? Rahul Chauhan

# %%
print("My name is " + name) # print function
# Out:
# My name is Rahul Chauhan

# %%
print(f"My name is {name}.") # f String
# Out:
# My name is Rahul Chauhan.

# %%
a = 10     # printing multiple variables
name = 'Rahul'
isStudent = False
print(a, name, isStudent)
# Out:
# 10 Rahul False

# %%
# input multiple values
x, y = input("Enter two values ").split()
print("First Value is ", x)
print("Second Value is ", y)
# Out:
# Enter two values  10 20
# First Value is  10
# Second Value is  20

# %%
# Changing type of input variables by default it is String so typecast needed
age = int(input("What is the age?"))
print(f"My age is {age}")
# Out:
# What is the age? 30
# My age is 30

# %%
# Finding Data types of Variables
a = 10
b = 20.0
c = "Rahul"
d = False
print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
